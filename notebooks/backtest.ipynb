# %% [markdown]
# # Backtest
#
# This notebook runs the rule-based BTC paper backtest using the feature dataset already generated by the pipeline.

# %%
from btcxpoly.config import load_config
from btcxpoly.storage import LocalStore
from btcxpoly.backtest import run_backtest

config = load_config('config.yaml')
store = LocalStore(config)
metrics = run_backtest(store, config)
metrics

# %%
trades = store.load_dataset('backtest_trades')
trades.head()
