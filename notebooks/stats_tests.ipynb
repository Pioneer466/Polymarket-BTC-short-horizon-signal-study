# %% [markdown]
# # Statistical Tests
#
# This notebook is the analysis entrypoint for lead-lag, calibration, and benchmark metrics.

# %%
from btcxpoly.config import load_config
from btcxpoly.storage import LocalStore
from btcxpoly.research import run_baseline

config = load_config('config.yaml')
store = LocalStore(config)
metrics = run_baseline(store, config)
metrics

# %%
features = store.load_dataset('features')
features.head()
